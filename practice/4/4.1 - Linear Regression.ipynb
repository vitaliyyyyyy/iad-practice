# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([1.38080108, 0.72989949, 3.79233288, 4.92685784, 2.39038883,
#        0.49972019, 3.72151226, 0.19710992, 1.09676179, 1.60557247,
#        1.18852189, 0.58451925, 4.05345025, 0.50615151, 1.11904489,
#        0.16724195, 2.15386968, 0.88080737, 2.4114985 , 0.38616288,
#        1.52939486, 4.92128947, 0.24251145, 0.98214974, 4.82823229,
#        3.40362143, 3.66714757, 3.1814625 , 2.57979367, 1.92655236,
#        1.72348882, 3.84336694, 4.31411372, 2.06407771, 1.44088214,
#        2.08738444, 4.4287288 , 3.05804518, 3.26597721, 0.27198402,
#        1.12653097, 2.10106415, 2.12144688, 2.28721825, 2.86669823,
#        3.5032307 , 4.0236875 , 2.92172722, 4.96416609, 0.7367442 ,
#        0.96335546, 0.07299954, 0.45255938, 4.35658019, 4.13061687,
#        3.4088522 , 2.93767151, 1.70034249, 3.72178718, 2.51680393,
#        2.96122206, 1.74108538, 4.1661647 , 1.01216028, 1.3598952 ,
#        0.75111281, 2.12911189, 4.65771314, 0.15958486, 4.21376891,
#        2.87835089, 3.13029212, 4.84167042, 1.36164684, 3.27012483,
#        3.09676318, 0.82303176, 4.65765954, 2.06868025, 1.6395547 ,
#        0.65978344, 1.34770294, 4.44121661, 2.82395001, 4.3355214 ,
#        4.96774776, 3.91439465, 2.65678306, 1.92710759, 3.34794312,
#        4.32351155, 1.71083269, 2.06365769, 2.47740953, 3.78381889,
#        4.41170922, 4.61053672, 3.04098118, 3.61654752, 2.34742245])

# %%
X # array where each row is an array to
# Out:
# array([[1.38080108],
#        [0.72989949],
#        [3.79233288],
#        [4.92685784],
#        [2.39038883],
#        [0.49972019],
#        [3.72151226],
#        [0.19710992],
#        [1.09676179],
#        [1.60557247],
#        [1.18852189],
#        [0.58451925],
#        [4.05345025],
#        [0.50615151],
#        [1.11904489],
#        [0.16724195],
#        [2.15386968],
#        [0.88080737],
#        [2.4114985 ],
#        [0.38616288],
#        [1.52939486],
#        [4.92128947],
#        [0.24251145],
#        [0.98214974],
#        [4.82823229],
#        [3.40362143],
#        [3.66714757],
#        [3.1814625 ],
#        [2.57979367],
#        [1.92655236],
#        [1.72348882],
#        [3.84336694],
#        [4.31411372],
#        [2.06407771],
#        [1.44088214],
#        [2.08738444],
#        [4.4287288 ],
#        [3.05804518],
#        [3.26597721],
#        [0.27198402],
#        [1.12653097],
#        [2.10106415],
#        [2.12144688],
#        [2.28721825],
#        [2.86669823],
#        [3.5032307 ],
#        [4.0236875 ],
#        [2.92172722],
#        [4.96416609],
#        [0.7367442 ],
#        [0.96335546],
#        [0.07299954],
#        [0.45255938],
#        [4.35658019],
#        [4.13061687],
#        [3.4088522 ],
#        [2.93767151],
#        [1.70034249],
#        [3.72178718],
#        [2.51680393],
#        [2.96122206],
#        [1.74108538],
#        [4.1661647 ],
#        [1.01216028],
#        [1.3598952 ],
#        [0.75111281],
#        [2.12911189],
#        [4.65771314],
#        [0.15958486],
#        [4.21376891],
#        [2.87835089],
#        [3.13029212],
#        [4.84167042],
#        [1.36164684],
#        [3.27012483],
#        [3.09676318],
#        [0.82303176],
#        [4.65765954],
#        [2.06868025],
#        [1.6395547 ],
#        [0.65978344],
#        [1.34770294],
#        [4.44121661],
#        [2.82395001],
#        [4.3355214 ],
#        [4.96774776],
#        [3.91439465],
#        [2.65678306],
#        [1.92710759],
#        [3.34794312],
#        [4.32351155],
#        [1.71083269],
#        [2.06365769],
#        [2.47740953],
#        [3.78381889],
#        [4.41170922],
#        [4.61053672],
#        [3.04098118],
#        [3.61654752],
#        [2.34742245]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(1.0324297165190979)

# %%
b_found
# Out:
# np.float64(2.8927563600482733)
